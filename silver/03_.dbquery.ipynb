-- %%
CREATE OR REFRESH MATERIALIZED VIEW vra_quarentena
COMMENT 'Silver quarentena - espelho DIAGNÓSTICO dos registros de silver.vra que
reprovaram em alguma expectation do contrato de dados, com o motivo por registro.
NÃO é filtro: silver.vra permanece com a contagem original. A decisão de excluir
ou não cada categoria é de negócio e acontece na gold.'
AS
SELECT
